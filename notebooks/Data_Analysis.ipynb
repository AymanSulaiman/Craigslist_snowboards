# %%
import os
import pandas as pd

# %%
df = pd.read_csv(os.path.join('..','data','snowboard_data.csv'))
df
# Out:
#                post_id                                              title  \
# 0    postid_7404893646                Dakine Snowboard 140 with  bindings
# 1    postid_7402218394      Morrow  Snowboard 148 cm with morrow bindings
# 2    postid_7410755840   Ride Snowboard 115 Cm and small Solomon bindings
# 3    postid_7407043907                             WOMENS SNOWBOARD BOOTS
# 4    postid_7413745357             Women’s Snowboard, Bindings, and Boots
# ..                 ...                                                ...
# 469  postid_7406161068                           Snowboards with bindings
# 470  postid_7411626803                                         Snowboards
# 471  postid_7408311060  Bird Scooter ES-1 Segway ES-1 Electric Scooter...
# 472  postid_7405832903                            Toyota Tacoma Roof Rack
# 473  postid_7405826278  Jeep Roof Rack Platform Wrangler Crossbars Wra...
#
#      price                           location  \
# ...

# %%
df[df.title.str.contains("snowboard")]
# Out:
#                post_id                                              title  \
# 5    postid_7402343887  Burton Joystick EST center channel V - Rocker ...
# 6    postid_7401629768  Burton Genesis EST snowboard bindings men’s me...
# 7    postid_7404088154  NEW 2022 Lib Tech Skate Banana snowboard 159 wide
# 9    postid_7402956731               Lib Tech Box Scratcher 154 snowboard
# 10   postid_7412592979     New women’s medium Burton snowboard ski jacket
# ..                 ...                                                ...
# 359  postid_7399300341               Burton snowboard and Bindings 121 CM
# 392  postid_7399000678       K2 Raider Boa Coiler snowboard boots size 11
# 393  postid_7400032808  New Marker ski snowboard helmets kids junior j...
# 441  postid_7404999094    Trespass snowboarding pants women's large white
# 448  postid_7412062907               Womens K2 snowboarding boots size 10
#
#      price                           location  \
# ...
